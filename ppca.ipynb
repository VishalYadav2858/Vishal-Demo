# %%
# # Demonstrating Tuples and Lists
# # Creating a tuple
# my_tuple = (1, 2, 3, 4, 5)
# print(&quot;Tuple:&quot;, my_tuple)
# # Creating a list
# my_list = [1, 2, 3, 4, 5]
# print(&quot;List:&quot;, my_list)

# # Differences between tuples and lists
# print(&quot;\nDifferences:&quot;)
# # Immutability of tuples
# try:
# my_tuple[0] = 10
# except TypeError as e:
# print(&quot;Tuples are immutable:&quot;, e)
# # Mutability of lists
# my_list[0] = 10
# print(&quot;Lists are mutable:&quot;, my_list)
# # Applications of tuples and lists
# # Lists can be used to store homogeneous items
# homogeneous_list = [1, 2, 3, 4, 5]
# print(&quot;\nHomogeneous list:&quot;, homogeneous_list)
# # Lists can be used to store heterogeneous items
# heterogeneous_list = [1, &quot;apple&quot;, 3.14, True]
# print(&quot;Heterogeneous list:&quot;, heterogeneous_list)
# # Tuples are used for fixed collections of items
# coordinates = (10, 20)
# print(&quot;\nCoordinates (tuple):&quot;, coordinates)
# # Lists are used for dynamic collections of items
# fruits = [&quot;apple&quot;, &quot;banana&quot;, &quot;cherry&quot;]
# print(&quot;Fruits (list):&quot;, fruits)
# # Adding elements to a list
# fruits.append(&quot;date&quot;)
# print(&quot;List after appending:&quot;, fruits)

# %%
# Demonstrating Tuples and Lists

# Creating a tuple
my_tuple = (1, 2, 3, 4, 5)
print("Tuple:", my_tuple)

# Creating a list
my_list = [1, 2, 3, 4, 5]
print("List:", my_list)

# Differences between tuples and lists
print("\nDifferences:")
# Immutability of tuples
try:
    my_tuple[0] = 10
except TypeError as e:
    print("Tuples are immutable:", e)

# Mutability of lists
my_list[0] = 10
print("Lists are mutable:", my_list)

# Applications of tuples and lists
# Lists can be used to store homogeneous items
homogeneous_list = [1, 2, 3, 4, 5]
print("\nHomogeneous list:", homogeneous_list)

# Lists can be used to store heterogeneous items
heterogeneous_list = [1, "apple", 3.14, True]
print("Heterogeneous list:", heterogeneous_list)

# Tuples are used for fixed collections of items
coordinates = (10, 20)
print("\nCoordinates (tuple):", coordinates)

# Lists are used for dynamic collections of items
fruits = ["apple", "banana", "cherry"]
print("Fruits (list):", fruits)

# Adding elements to a list
fruits.append("date")
print("List after appending:", fruits)
# Out:
# Tuple: (1, 2, 3, 4, 5)
# List: [1, 2, 3, 4, 5]
#
# Differences:
# Tuples are immutable: 'tuple' object does not support item assignment
# Lists are mutable: [10, 2, 3, 4, 5]
#
# Homogeneous list: [1, 2, 3, 4, 5]
# Heterogeneous list: [1, 'apple', 3.14, True]
#
# Coordinates (tuple): (10, 20)
# Fruits (list): ['apple', 'banana', 'cherry']
# List after appending: ['apple', 'banana', 'cherry', 'date']

# %%
def binary_to_decimal(binary_str):
    decimal = 0
    power = 0
    for digit in reversed(binary_str):
        if digit == "1":
            decimal += 2 ** power
        power += 1
    return decimal

def decimal_to_binary(decimal_num):
    if decimal_num == 0:
        return "0"
    binary_str = ""
    while decimal_num > 0:
        binary_str = str(decimal_num % 2) + binary_str
        decimal_num //= 2
    return binary_str

# Input binary from user
binar_1 = input("Enter first binary number: ")
binar_2 = input("Enter second binary number: ")

# Convert binary to decimal value
decimal_1 = binary_to_decimal(binar_1)
decimal_2 = binary_to_decimal(binar_2)

# Performing addition and multiplication
sum_decimal = decimal_1 + decimal_2
mul_decimal = decimal_1 * decimal_2

# Converting back to binary
sum_bin = decimal_to_binary(sum_decimal)
mul_bin = decimal_to_binary(mul_decimal)

print("Sum in binary:", sum_bin)
print("Multiplication in binary:", mul_bin)
# Out:
# Sum in binary: 101001010
# Multiplication in binary: 110101001011001

# %%
# Function to convert binary string to decimal
def binary_to_decimal(binary_str):
    decimal = 0
    power = 0
    for digit in reversed(binary_str):
        if digit == "1":
            decimal += 2**power
        power += 1
    return decimal


# Function to convert decimal to binary string
def decimal_to_binary(decimal_num):
    if decimal_num == 0:
        return "0"
    binary_str = ""
    while decimal_num > 0:
        binary_str = str(decimal_num % 2) + binary_str
        decimal_num //= 2
    return binary_str


# Input binary from user
binary_1 = input("Enter first binary number: ")
binary_2 = input("Enter second binary number: ")

# Convert binary to decimal manually using functions
dec_1 = binary_to_decimal(binary_1)
sum_2 = binary_to_decimal(binary_2)

# Performing addition and multiplication
sum_dec = dec_1 + sum_2
mul_dec = dec_1 * sum_2

# Converting result back to binary
sum_bin = decimal_to_binary(sum_dec)
mul_bin = decimal_to_binary(mul_dec)

# Displaying Results
print(f"Decimal of {binary_1} = {dec_1}")
print(f"Decimal of {binary_2} = {sum_2}")
print(f"Addition of binary = {sum_bin} (decimal: {sum_dec})")
print(f"Multiplication of binary = {mul_bin} (decimal: {mul_dec})")
# Out:
# Decimal of 1000011 = 67
# Decimal of 000011 = 3
# Addition of binary = 1000110 (decimal: 70)
# Multiplication of binary = 11001001 (decimal: 201)

# %%
# Experiment 06: File Handling Operations

# 1. Write to a file (w mode)
file = open("sample.txt", "w")
file.write("Hello, this is a file handling demo.\n")
file.write("We are writing into the file.\n")
file.close()

# 2. Read from the file (r mode)
file = open("sample.txt", "r")
print("Reading file contents:")
print(file.read())
file.close()

# 3. Append new data (a mode)
file = open("sample.txt", "a")
file.write("This line is appended at the end.\n")
file.close()

# 4. Read again after append
file = open("sample.txt", "r")
print("Reading after appending:")
print(file.read())
file.close()

# 5. Read & Write (r+ mode)
file = open("sample.txt", "r+")
content = file.read()
print("Content in r+ mode:", content)
file.write("Adding text using r+ mode.\n")
file.close()

# 6. Write & Read (w+ mode)
file = open("newfile.txt", "w+")
file.write("This is created using w+ mode.\n")
file.seek(0)   # move file pointer to start
print("Reading from newfile.txt:")
print(file.read())
file.close()

# 7. Append & Read (a+ mode)
file = open("sample.txt", "a+")
file.write("Extra line using a+ mode.\n")
file.seek(0)
print("Reading with a+ mode:")
print(file.read())
file.close()





import os

# 1. Check if a file exists
if os.path.exists("sample.txt"):
    print("✅ sample.txt exists")
else:
    print("❌ sample.txt does not exist")

# 2. Rename a file
os.rename("sample.txt", "renamed_sample.txt")
print("File renamed to renamed_sample.txt")

# 3. Delete a file
if os.path.exists("renamed_sample.txt"):
    os.remove("renamed_sample.txt")
    print("File deleted successfully")

# 4. Create a new directory
os.mkdir("myfolder")
print("Directory 'myfolder' created")

# 5. Create a file inside the directory
with open("myfolder/test.txt", "w") as f:
    f.write("File created inside folder")

# 6. List files in the directory
print("Files in myfolder:", os.listdir("myfolder"))

# 7. Remove directory (must be empty)
os.remove("myfolder/test.txt")   # delete file inside
os.rmdir("myfolder")
print("Directory 'myfolder' removed")

# %%
# 1. Write to a file (w mode)
file = open("sample.txt", "w")
file.write("Hello, this is a file handling demo.\n")
file.write("We are writing into the file.\n")
file.close()
print(file.write)
print(file.write)
print(file.write)
# Out:
# <built-in method write of _io.TextIOWrapper object at 0x1086d4200>
# <built-in method write of _io.TextIOWrapper object at 0x1086d4200>
# <built-in method write of _io.TextIOWrapper object at 0x1086d4200>

# %%
import os

f = open("info.txt")
if f:
    print("opened")
else:
    print("not")
    

file = open("info.txt", "a")
file.write("Hello, this is a file handling demo.\n")
file.write("We are writing into the file.\n")
file.close()

file = open("sample.txt", "r")
print("Reading file contents:")
print(file.read())
file.close()


# 2. Rename a file
os.rename("info.txt", "renamed_sample.txt")
print("File renamed to renamed_sample.txt")




# 3. Delete a file
if os.path.exists("renamed_sample.txt"):
    os.remove("renamed_sample.txt")
    print("File deleted successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 import os
# ----> 3 f = open("info.txt")
#       4 if f:
#       5     print("opened")
#
# File /opt/anaconda3/envs/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'info.txt'
